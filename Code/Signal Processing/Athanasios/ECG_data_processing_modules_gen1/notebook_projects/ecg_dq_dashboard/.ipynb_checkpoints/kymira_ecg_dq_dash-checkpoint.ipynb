# %% [markdown]
# # ECG Signal Explorer

# %%
import copy
from kymira_data_in import read_ecg_trial
# Pre-processing functions
from kymira_ecg.preprocessing import butterworth_bandpass_filtering, notch_filtering, wavelet_denoising
from kymira_ecg.visualisation import plot_ecg_bokeh
import ipywidgets

# %% [markdown]
# ## Work on:

# %%
channels = ["ECG_1","ECG_2","A_X","A_Y","A_Z","G_X","G_Y","G_Z","M_X","M_Y","M_Z","M_rH"]

# %%
Location = "/home/protopi/RaspberryPi_Dev/Test_Brain-Beta-v1-1_13-04_2022-05-19_v0.csv"
kymira_ecg_data = read_ecg_trial(Location)
print(kymira_ecg_data)
# Out:
#           ECG_1     ECG_2        A_X       A_Y       A_Z       G_X       G_Y  \
# 0      0.036158  0.016030  -0.125488 -0.250488  3.503906 -0.750488 -0.250488
# 1      0.039309  0.027718  -0.125488 -0.250488  3.503906 -0.750488 -0.250488
# 2      0.048746  0.054443  -0.125488 -0.250488  3.503906 -0.750488 -0.250488
# 3      0.056707  0.057931  -0.125488 -0.250488  3.503906 -0.750488 -0.250488
# 4      0.056523  0.058062  -0.125488 -0.250488  3.503906 -0.750488 -0.250488
# ...         ...       ...        ...       ...       ...       ...       ...
# 17426  0.054540  0.047038  13.125000  0.375000  2.878906 -0.500488 -2.500488
# 17427  0.056498  0.058170  13.125000  0.375000  2.878906 -0.500488 -2.500488
# 17428  0.057503  0.058768  13.125000  0.375000  2.878906 -0.500488 -2.500488
# 17429  0.055745  0.058811  13.125000  0.375000  2.878906 -0.500488 -2.500488
# 17430  0.054729  0.058733  13.375000  0.000000  3.628906 -0.500488 -0.625488
#
#             G_Z     M_X        M_Y     M_Z       M_rH  \
# 0     -0.625488  15.125  -1.750977  15.125  13.178223
# 1     -0.625488  15.125  -1.750977  15.125  13.178223
# 2     -0.625488  15.125  -1.750977  15.125  13.178223
# 3     -0.625488  15.125  -1.750977  15.125  13.178223
# 4     -0.625488  15.125  -1.750977  15.125  13.178223
# ...         ...     ...        ...     ...        ...
# 17426 -0.125488  11.125  -9.750977  14.875   4.678223
# 17427 -0.125488  11.125  -9.750977  14.875   4.678223
# 17428 -0.125488  11.125  -9.750977  14.875   4.678223
# 17429 -0.125488  11.125  -9.750977  14.875   4.678223
# 17430 -0.625488  13.125 -10.750977  15.125   4.178223
#
#                           tstamp
# 0     2022-05-19 11:15:25.888193
# 1     2022-05-19 11:15:25.890193
# 2     2022-05-19 11:15:25.892193
# 3     2022-05-19 11:15:25.894193
# 4     2022-05-19 11:15:25.896193
# ...                          ...
# 17426 2022-05-19 11:16:00.740193
# 17427 2022-05-19 11:16:00.742193
# 17428 2022-05-19 11:16:00.744193
# 17429 2022-05-19 11:16:00.746193
# 17430 2022-05-19 11:16:00.748193
#
# [17431 rows x 13 columns]

# %% [markdown]
# ## Time domain plot:

# %%
plot_ecg_bokeh(kymira_ecg_data,channels=channels)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2205">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="92a60d46-e79c-48f1-8b92-ab6ff2c1dc17" data-root-id="2591"></div>

# %% [markdown]
# ## Pre-processing

# %%
def temp_preprocess(apply_notch, apply_detrend, wt_denoise_level):
    """
    Applies the pre-processing.
    
    Notes:
        * This is a TEMPORARY function (the pre-processing pipeline is formalised).
    """
    pre_processed = copy.deepcopy(kymira_ecg_data)
    
    for a_channel in channels:
        stage_1 = notch_filtering(pre_processed[f"ecg{a_channel}"]) if apply_notch else pre_processed[f"ecg{a_channel}"]
        stage_2 = butterworth_bandpass_filtering(stage_1, 0.5, 40, 4, 500) if apply_detrend else stage_1
        stage_3 = wavelet_denoising(stage_2, denoise_level=1.0-wt_denoise_level)
        pre_processed[f"ecg{a_channel}"] = stage_3
        
    plot_ecg_bokeh(pre_processed,channels=channels)
    
    

ipywidgets.interact(temp_preprocess, 
                    apply_notch = ipywidgets.Checkbox(value=False, description="50 Hz notch", indent=False), 
                    apply_detrend = ipywidgets.Checkbox(value=False, description="0.5Hz - 40Hz Bandpass filter", indent=False),
                    wt_denoise_level = ipywidgets.FloatSlider(value=0, min=0.0, max=1.0, step=0.01, continuous_update=False, description="Wavelet denoise level"))
# Out:
# interactive(children=(Checkbox(value=False, description='50 Hz notch', indent=False), Checkbox(value=False, de…
# <function __main__.temp_preprocess(apply_notch, apply_detrend, wt_denoise_level)>
